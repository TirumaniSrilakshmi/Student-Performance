# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("StudentsPerformance.csv")

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
data.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
data['Total Score']= data['math score']+data['reading score']+data['writing score']

# %%
data.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Total Score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %%
data['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
labels = 'Female','male'
plt.pie(data['gender'].value_counts(),labels= labels,shadow = True, explode = [0.1,0.01] ,autopct  = '%2f%%')
plt.title('Gender pie plt', fontsize = 10)
plt.grid()

# %%
data['lunch'].value_counts()
# Out:
# lunch
# standard        645
# free/reduced    355
# Name: count, dtype: int64

# %%
labels ='standard','free/reduced' 
plt.pie(data['lunch'].value_counts(),shadow = True,explode = [0,0.1], autopct ='%2f%%')
plt.title('lunch pie chart')
# Out:
# Text(0.5, 1.0, 'lunch pie chart')

# %%
data['race/ethnicity'].value_counts()
# Out:
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64

# %%
data['race/ethnicity'].value_counts(dropna = False).plot.bar()
plt.title('race/ethnicity',fontsize = 10)
plt.xlabel('Race/ethnicity')
plt.ylabel('count')
plt.show()

# %%
data['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64

# %%
data['parental level of education'].value_counts().plot.bar()
plt.title('parental level of education',fontsize = 10)
plt.xlabel('Degree')
plt.ylabel('count')
plt.show()

# %%
plt.boxplot(data['math score'])
plt.title("Math Score")
plt.show()

# %%
plt.boxplot(data['reading score'])
plt.title("Reading Score")
plt.show()

# %%
plt.boxplot(data['writing score'])
plt.title("Writing Score")
plt.show()

# %%
sns.displot(data['math score'])
plt.title('Math Score Displot', fontsize = 10)
plt.xlabel('Score')
plt.ylabel('count')

sns.displot(data['reading score'])
plt.title('Reading Score', fontsize = 10)
plt.xlabel('Score')
plt.ylabel('Count')

sns.displot(data['writing score'])
plt.title('Writing Score', fontsize = 10)
plt.xlabel('Score')
plt.ylabel('Count')

plt.show()

# %%
#gender vs race/etnicity

x = pd.crosstab(data['gender'],data['race/ethnicity'])
x
# Out:
# race/ethnicity  group A  group B  group C  group D  group E
# gender
# female               36      104      180      129       69
# male                 53       86      139      133       71

# %%
x_normalised = x.div(x.sum(1).astype(float), axis  = 0)
x_normalised
# Out:
# race/ethnicity   group A   group B   group C   group D   group E
# gender
# female          0.069498  0.200772  0.347490  0.249035  0.133205
# male            0.109959  0.178423  0.288382  0.275934  0.147303

# %%
x_normalised.plot(kind = 'bar',stacked = False)
plt.title("gender vs race/etnicity")
plt.show()

# %%
# most of female are from group c and males are mostly from group c and d

# %%
# race/ethnicity vs parental level of education
x = pd.crosstab(data['race/ethnicity'],data['parental level of education'])
x
# Out:
# parental level of education  associate's degree  bachelor's degree  \
# race/ethnicity
# group A                                      14                 12
# group B                                      41                 20
# group C                                      78                 40
# group D                                      50                 28
# group E                                      39                 18
#
# parental level of education  high school  master's degree  some college  \
# race/ethnicity
# group A                               18                3            18
# group B                               48                6            37
# group C                               64               19            69
# group D                               44               23            67
# group E                               22                8            35
#
# parental level of education  some high school
# race/ethnicity
# ...

# %%
x.sum(1)
# Out:
# race/ethnicity
# group A     89
# group B    190
# group C    319
# group D    262
# group E    140
# dtype: int64

# %%
x_normalise =x.div(x.sum(1).astype(float),axis =0)
x_normalise
# Out:
# parental level of education  associate's degree  bachelor's degree  \
# race/ethnicity
# group A                                0.157303           0.134831
# group B                                0.215789           0.105263
# group C                                0.244514           0.125392
# group D                                0.190840           0.106870
# group E                                0.278571           0.128571
#
# parental level of education  high school  master's degree  some college  \
# race/ethnicity
# group A                         0.202247         0.033708      0.202247
# group B                         0.252632         0.031579      0.194737
# group C                         0.200627         0.059561      0.216301
# group D                         0.167939         0.087786      0.255725
# group E                         0.157143         0.057143      0.250000
#
# parental level of education  some high school
# race/ethnicity
# ...

# %%
x_normalise.plot(kind = 'bar',stacked = False)
plt.title("race/ethnicity vs parental level of education",fontsize= 20)
# Out:
# Text(0.5, 1.0, 'race/ethnicity vs parental level of education')

# %%
# form above grapgh we conclude that in all the groups , parents level of education i.e., who did masters is very less

# %%
# gender vs parental level of education

# %%
x = pd.crosstab(data["gender"],data["parental level of education"])
x
# Out:
# parental level of education  associate's degree  bachelor's degree  \
# gender
# female                                      116                 63
# male                                        106                 55
#
# parental level of education  high school  master's degree  some college  \
# gender
# female                                94               36           118
# male                                 102               23           108
#
# parental level of education  some high school
# gender
# female                                     91
# male                                       88

# %%
x_normalise = x.div(x.sum(1).astype(float),axis = 0)
x_normalise
# Out:
# parental level of education  associate's degree  bachelor's degree  \
# gender
# female                                 0.223938           0.121622
# male                                   0.219917           0.114108
#
# parental level of education  high school  master's degree  some college  \
# gender
# female                          0.181467         0.069498      0.227799
# male                            0.211618         0.047718      0.224066
#
# parental level of education  some high school
# gender
# female                               0.175676
# male                                 0.182573

# %%
x_normalise.plot(kind = 'bar',stacked = False)
plt.title("gender vs parental level of education", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'gender vs parental level of education')

# %%
data.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    Total Score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %%
#  race/ethnicity vs test preparation course
sns.countplot(data= data,x = 'race/ethnicity',hue= "test preparation course" ,palette ='Blues' )
plt.title("race/ethnicity vs test preparation course",fontsize = 20)
plt.show()

# %%
# parental level of education vs test preparation course

# %%
sns.countplot(data=data,x = "parental level of education", hue = "test preparation course",palette = 'Greens')
plt.title("parental level of education vs test preparation course", fontsize = 20)
plt.show()

# %%
# feature engineering on the data to visualize and solve the dataset more accurately

# setting a passing mark for the students to pass on the three subjects individually
passmarks = 40

data["Math_pass"] = np.where(data['math score']>passmarks,"Pass","Fail")

# %%
data["reading_pass"]= np.where(data["reading score"]>passmarks,"Pass","Fail")	
data["writing_pass"]=np.where(data["writing score"]>passmarks,"Pass","Fail")

# %%
data.head(3)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
#
#    Total Score Math_pass reading_pass writing_pass  Total_Percentage
# 0          218      Pass         Pass         Pass         72.666667
# 1          247      Pass         Pass         Pass         82.333333
# 2          278      Pass         Pass         Pass         92.666667

# %%
data["Math_pass"].value_counts()
# Out:
# Math_pass
# Pass    950
# Fail     50
# Name: count, dtype: int64

# %%
data["reading_pass"].value_counts()
# Out:
# reading_pass
# Pass    973
# Fail     27
# Name: count, dtype: int64

# %%
data["writing_pass"].value_counts()
# Out:
# writing_pass
# pass    965
# Fail     35
# Name: count, dtype: int64

# %%
plt.pie(data["Math_pass"].value_counts(),labels = ("Pass","Fail")
        ,shadow = True,explode = (.1,.1),autopct = '%2f%%')
plt.title("Math_pass")
plt.show()

# %%
plt.pie(data["reading_pass"].value_counts(),labels = ("Pass","Fail"),shadow = True,explode = (.1,.1),autopct = "%2f%%")
plt.title("eading_pass")
plt.show()

# %%
plt.pie(data["writing_pass"].value_counts(),labels = ("Pass","True"),explode = (.1,.1),shadow = True,autopct = "%2f%%")
plt.title("writing_pass")
plt.show()

# %%
# Total Pass Percentage 

data["Total_Percentage"] = data["Total Score"]/3

# %%
data.head(3)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
#
#    Total Score Math_pass reading_pass writing_pass  Total_Percentage
# 0          218      Pass         Pass         pass         72.666667
# 1          247      Pass         Pass         pass         82.333333
# 2          278      Pass         Pass         pass         92.666667

# %%
sns.displot(data["Total Score"])
plt.title("Total score distribution")
plt.xlabel('total score scored by the students')
plt.ylabel('count')
# Out:
# Text(4.944444444444445, 0.5, 'count')

# %%
sns.displot(data["Total_Percentage"])
plt.title("Total percentage distribution")
plt.xlabel('total precentage scored by the students')
plt.ylabel('count')
# Out:
# Text(4.944444444444445, 0.5, 'count')

# %%
data.head(2)
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
#
#    Total Score Math_pass reading_pass writing_pass  Total_Percentage
# 0          218      Pass         Pass         Pass         72.666667
# 1          247      Pass         Pass         Pass         82.333333

# %%
data.columns
data['Math_pass']
# Out:
# 0      Pass
# 1      Pass
# 2      Pass
# 3      Pass
# 4      Pass
#        ...
# 995    Pass
# 996    Pass
# 997    Pass
# 998    Pass
# 999    Pass
# Name: Math_pass, Length: 1000, dtype: object

# %%
# checking which student is fail overall
data['PassFailStatus'] = data.apply(lambda x: "Fail" 
                                    if x['Math_pass'] == "Fail" or 
                                    x["reading_pass"] == "Fail" or 
                                    x["writing_pass"] == "Fail" 
                                    else "Pass" , axis = 1)


sns.countplot(x = data["PassFailStatus"],palette = "muted" , hue =data["PassFailStatus"] )
plt.title("Pass Fail Overall Status")
plt.show()
